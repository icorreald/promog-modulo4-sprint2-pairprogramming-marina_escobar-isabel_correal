# %% [markdown]
# # API SPOTIFY

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np

from src import api_soporte as api

# %%
sp = api.credenciales()

# %%
lista_discos = ['https://open.spotify.com/album/5eyZZoQEFQWRHkV2xgAeBw?si=QfZUzkisSweWF6f5Zw48SQ', # debut
                'https://open.spotify.com/album/6tgMb6LEwb3yj7BdYy462y?si=KMuHR1gFSUabKJnnBBpmfA', # fearless
                'https://open.spotify.com/album/6S6JQWzUrJVcJLK4fi74Fw?si=Y28PyIx-S2KlQj7MHk11TA', # speak now (deluxe)
                'https://open.spotify.com/intl-es/album/1KVKqWeRuXsJDLTW0VuD29?si=4ObfYoNORsaeV85ZUdfxZw', # red
                'https://open.spotify.com/album/1yGbNOtRIgdIiGHOEBaZWf?si=cQmUCtaYTq2MXY-G9jA8-Q', # 1989 deluxe
                'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv?si=XTd1zjmRSI-yMgw9tB1Stg', # reputa
                'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq?si=VyPthD5zR5yqq27y4qgUyw', # lover
                'https://open.spotify.com/album/1pzvBxYgT6OVwJLtHkrdQK?si=KtiGk4TYQCapyGHhnZwavA', # folklore
                'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG?si=hcY11QxLR4OX8LDkNVtwOw', # evermore
                'https://open.spotify.com/album/3lS1y25WAhcqJDATJK70Mq?si=XPoxfq8iTU6GVBKZK9sMfg', # midnights (3am)
                'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb?si=idsuy6fzS0GIUdFBYqOKGQ'] # ttpd (2am)

lista_uri = []
for link in lista_discos:
    lista_uri.append(link.split('/')[-1].split('?')[0])

lista_uri
# Out:
# ['5eyZZoQEFQWRHkV2xgAeBw',
#  '6tgMb6LEwb3yj7BdYy462y',
#  '6S6JQWzUrJVcJLK4fi74Fw',
#  '1KVKqWeRuXsJDLTW0VuD29',
#  '1yGbNOtRIgdIiGHOEBaZWf',
#  '6DEjYFkNZh67HP7R9PSZvv',
#  '1NAmidJlEaVgA3MpcPFYGq',
#  '1pzvBxYgT6OVwJLtHkrdQK',
#  '6AORtDjduMM3bupSWzbTSG',
#  '3lS1y25WAhcqJDATJK70Mq',
#  '5H7ixXZfsNMGbIE5OBSpcb']

# %%
lista_datos_discos = []
for uri in lista_uri:
    lista_datos_discos.append(sp.album(uri))
lista_datos_discos
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'GB',
#    'ID',
#    'JP',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LR',
#    'MW',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'AZ',
#    'BN',
#    'BI',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GN',
#    'KG',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'ZM',
#    'CD',
#    'CG',
#    'TJ',
#    'VE',
#    'XK'],
#   'copyrights': [{'text': '© 2008 Apollo A-1 LLC', 'type': 'C'},
#    {'text': '℗ 2008 Apollo A-1 LLC', 'type': 'P'}],
#   'external_ids': {'upc': '00602517874695'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5eyZZoQEFQWRHkV2xgAeBw'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/5eyZZoQEFQWRHkV2xgAeBw',
#   'id': '5eyZZoQEFQWRHkV2xgAeBw',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c909d4e47de2ab0636f46d64',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c909d4e47de2ab0636f46d64',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c909d4e47de2ab0636f46d64',
#     'width': 64}],
#   'label': 'Universal Music',
#   'name': 'Taylor Swift',
#   'popularity': 73,
#   'release_date': '2006-10-24',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/5eyZZoQEFQWRHkV2xgAeBw/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 232106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2Fn01AIMyHbha2ceNQeOqw'},
#      'href': 'https://api.spotify.com/v1/tracks/2Fn01AIMyHbha2ceNQeOqw',
#      'id': '2Fn01AIMyHbha2ceNQeOqw',
#      'is_local': False,
#      'name': 'Tim McGraw',
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2Fn01AIMyHbha2ceNQeOqw'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 173066,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4BYejINgfZF0qKDMEH2cim'},
#      'href': 'https://api.spotify.com/v1/tracks/4BYejINgfZF0qKDMEH2cim',
#      'id': '4BYejINgfZF0qKDMEH2cim',
#      'is_local': False,
#      'name': 'Picture To Burn',
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:4BYejINgfZF0qKDMEH2cim'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 203040,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2TF4UtYreqNbQ6Z9AccldU'},
#      'href': 'https://api.spotify.com/v1/tracks/2TF4UtYreqNbQ6Z9AccldU',
#      'id': '2TF4UtYreqNbQ6Z9AccldU',
#      'is_local': False,
#      'name': 'Teardrops On My Guitar - Radio Single Remix',
#      'preview_url': None,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:2TF4UtYreqNbQ6Z9AccldU'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 199200,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1oR4MUBpyNrAViC8wPNpfm'},
#      'href': 'https://api.spotify.com/v1/tracks/1oR4MUBpyNrAViC8wPNpfm',
#      'id': '1oR4MUBpyNrAViC8wPNpfm',
#      'is_local': False,
#      'name': 'A Place in this World',
#      'preview_url': None,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:1oR4MUBpyNrAViC8wPNpfm'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 239013,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/569sXXQ7t0jSdqHooi2yqs'},
#      'href': 'https://api.spotify.com/v1/tracks/569sXXQ7t0jSdqHooi2yqs',
#      'id': '569sXXQ7t0jSdqHooi2yqs',
#      'is_local': False,
#      'name': 'Cold As You',
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:569sXXQ7t0jSdqHooi2yqs'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 207106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5Tj2MqcFMf60CaGsKbM1aq'},
#      'href': 'https://api.spotify.com/v1/tracks/5Tj2MqcFMf60CaGsKbM1aq',
#      'id': '5Tj2MqcFMf60CaGsKbM1aq',
#      'is_local': False,
#      'name': 'The Outside',
#      'preview_url': None,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5Tj2MqcFMf60CaGsKbM1aq'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 248106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2zzxwmoOBnXDT0KnJsoIWk'},
#      'href': 'https://api.spotify.com/v1/tracks/2zzxwmoOBnXDT0KnJsoIWk',
#      'id': '2zzxwmoOBnXDT0KnJsoIWk',
#      'is_local': False,
#      'name': 'Tied Together with a Smile',
#      'preview_url': None,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:2zzxwmoOBnXDT0KnJsoIWk'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 236053,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/41sjzdjScVwnxnxADElts6'},
#      'href': 'https://api.spotify.com/v1/tracks/41sjzdjScVwnxnxADElts6',
#      'id': '41sjzdjScVwnxnxADElts6',
#      'is_local': False,
#      'name': 'Stay Beautiful',
#      'preview_url': None,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:41sjzdjScVwnxnxADElts6'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 242200,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6CdaXOq1MWe2JHDalTG01d'},
#      'href': 'https://api.spotify.com/v1/tracks/6CdaXOq1MWe2JHDalTG01d',
#      'id': '6CdaXOq1MWe2JHDalTG01d',
#      'is_local': False,
#      'name': "Should've Said No",
#      'preview_url': None,
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:6CdaXOq1MWe2JHDalTG01d'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 213080,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2O8sogKJCfVZ4rotBv1vVF'},
#      'href': 'https://api.spotify.com/v1/tracks/2O8sogKJCfVZ4rotBv1vVF',
#      'id': '2O8sogKJCfVZ4rotBv1vVF',
#      'is_local': False,
#      'name': "Mary's Song (Oh My My My)",
#      'preview_url': None,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:2O8sogKJCfVZ4rotBv1vVF'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 201106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1j6gmK6u4WNI33lMZ8dC1s'},
#      'href': 'https://api.spotify.com/v1/tracks/1j6gmK6u4WNI33lMZ8dC1s',
#      'id': '1j6gmK6u4WNI33lMZ8dC1s',
#      'is_local': False,
#      'name': 'Our Song',
#      'preview_url': None,
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:1j6gmK6u4WNI33lMZ8dC1s'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 213053,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7CzxXgQXurKZCyHz9ufbo1'},
#      'href': 'https://api.spotify.com/v1/tracks/7CzxXgQXurKZCyHz9ufbo1',
#      'id': '7CzxXgQXurKZCyHz9ufbo1',
#      'is_local': False,
#      'name': "I'm Only Me When I'm With You",
#      'preview_url': None,
#      'track_number': 12,
#      'type': 'track',
#      'uri': 'spotify:track:7CzxXgQXurKZCyHz9ufbo1'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 203226,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1k3PzDNjg38cWqOvL4M9vq'},
#      'href': 'https://api.spotify.com/v1/tracks/1k3PzDNjg38cWqOvL4M9vq',
#      'id': '1k3PzDNjg38cWqOvL4M9vq',
#      'is_local': False,
#      'name': 'Invisible',
#      'preview_url': None,
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:1k3PzDNjg38cWqOvL4M9vq'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 220146,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0YgHuReCSPwTXYny7isLja'},
#      'href': 'https://api.spotify.com/v1/tracks/0YgHuReCSPwTXYny7isLja',
#      'id': '0YgHuReCSPwTXYny7isLja',
#      'is_local': False,
#      'name': 'A Perfectly Good Heart',
#      'preview_url': None,
#      'track_number': 14,
#      'type': 'track',
#      'uri': 'spotify:track:0YgHuReCSPwTXYny7isLja'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 179066,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1hxLyjC9D9Jpw6EAPKqWv4'},
#      'href': 'https://api.spotify.com/v1/tracks/1hxLyjC9D9Jpw6EAPKqWv4',
#      'id': '1hxLyjC9D9Jpw6EAPKqWv4',
#      'is_local': False,
#      'name': 'Teardrops on My Guitar - Pop Version',
#      'preview_url': None,
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1hxLyjC9D9Jpw6EAPKqWv4'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 15},
#   'type': 'album',
#   'uri': 'spotify:album:5eyZZoQEFQWRHkV2xgAeBw'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#   'copyrights': [{'text': '© 2009 Apollo A-1 LLC', 'type': 'C'},
#    {'text': '℗ 2009 Apollo A-1 LLC', 'type': 'P'}],
#   'external_ids': {'upc': '00602517999381'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6tgMb6LEwb3yj7BdYy462y'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/6tgMb6LEwb3yj7BdYy462y',
#   'id': '6tgMb6LEwb3yj7BdYy462y',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736ff72554305455511e786687',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026ff72554305455511e786687',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516ff72554305455511e786687',
#     'width': 64}],
#   'label': 'Big Machine Records, LLC',
#   'name': 'Fearless',
#   'popularity': 39,
#   'release_date': '2008-11-11',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/6tgMb6LEwb3yj7BdYy462y/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#      'disc_number': 1,
#      'duration_ms': 243400,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4lIbdZwGa2hgkxigHJumaV'},
#      'href': 'https://api.spotify.com/v1/tracks/4lIbdZwGa2hgkxigHJumaV',
#      'id': '4lIbdZwGa2hgkxigHJumaV',
#      'is_local': False,
#      'name': 'Fearless',
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4lIbdZwGa2hgkxigHJumaV'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#      'disc_number': 1,
#      'duration_ms': 295213,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2l9Pipz6AiVOabtKJVl3O9'},
#      'href': 'https://api.spotify.com/v1/tracks/2l9Pipz6AiVOabtKJVl3O9',
#      'id': '2l9Pipz6AiVOabtKJVl3O9',
#      'is_local': False,
#      'name': 'Fifteen',
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:2l9Pipz6AiVOabtKJVl3O9'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
# ...
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 249807,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/18WFFUIsewmA8g31KAeo3e'},
#      'href': 'https://api.spotify.com/v1/tracks/18WFFUIsewmA8g31KAeo3e',
#      'id': '18WFFUIsewmA8g31KAeo3e',
#      'is_local': False,
#      'name': 'The Prophecy',
#      'preview_url': None,
#      'track_number': 26,
#      'type': 'track',
#      'uri': 'spotify:track:18WFFUIsewmA8g31KAeo3e'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 240205,
#      'explicit': True,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0g4fMVo4JjwnIpTfFfLdxS'},
#      'href': 'https://api.spotify.com/v1/tracks/0g4fMVo4JjwnIpTfFfLdxS',
#      'id': '0g4fMVo4JjwnIpTfFfLdxS',
#      'is_local': False,
#      'name': 'Cassandra',
#      'preview_url': None,
#      'track_number': 27,
#      'type': 'track',
#      'uri': 'spotify:track:0g4fMVo4JjwnIpTfFfLdxS'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 283957,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3zMDGj4D8ogaYgAIZPeU7S'},
#      'href': 'https://api.spotify.com/v1/tracks/3zMDGj4D8ogaYgAIZPeU7S',
#      'id': '3zMDGj4D8ogaYgAIZPeU7S',
#      'is_local': False,
#      'name': 'Peter',
#      'preview_url': None,
#      'track_number': 28,
#      'type': 'track',
#      'uri': 'spotify:track:3zMDGj4D8ogaYgAIZPeU7S'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 238241,
#      'explicit': True,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2913xXOVAIDAqxzV2g4VcU'},
#      'href': 'https://api.spotify.com/v1/tracks/2913xXOVAIDAqxzV2g4VcU',
#      'id': '2913xXOVAIDAqxzV2g4VcU',
#      'is_local': False,
#      'name': 'The Bolter',
#      'preview_url': None,
#      'track_number': 29,
#      'type': 'track',
#      'uri': 'spotify:track:2913xXOVAIDAqxzV2g4VcU'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 240893,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2CnjDMdpRjlWv04Xk3s6MW'},
#      'href': 'https://api.spotify.com/v1/tracks/2CnjDMdpRjlWv04Xk3s6MW',
#      'id': '2CnjDMdpRjlWv04Xk3s6MW',
#      'is_local': False,
#      'name': 'Robin',
#      'preview_url': None,
#      'track_number': 30,
#      'type': 'track',
#      'uri': 'spotify:track:2CnjDMdpRjlWv04Xk3s6MW'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 224743,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1DTRUYVd8rYpla9hhVVwjo'},
#      'href': 'https://api.spotify.com/v1/tracks/1DTRUYVd8rYpla9hhVVwjo',
#      'id': '1DTRUYVd8rYpla9hhVVwjo',
#      'is_local': False,
#      'name': 'The Manuscript',
#      'preview_url': None,
#      'track_number': 31,
#      'type': 'track',
#      'uri': 'spotify:track:1DTRUYVd8rYpla9hhVVwjo'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 31},
#   'type': 'album',
#   'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb'}]

# %%
dataframe_discos = {'disco':[],
                    'release_date': [],
                    'markets': [],
                    'label': [],
                    'total_tracks': []}
for disco in lista_datos_discos:
    dataframe_discos['disco'].append(disco['name'])
    dataframe_discos['release_date'].append(disco['release_date'])
    dataframe_discos['markets'].append(disco['available_markets'])
    dataframe_discos['label'].append(disco['label'])
    dataframe_discos['total_tracks'].append(disco['total_tracks'])

df = pd.DataFrame(dataframe_discos)
df.to_csv('files/general_info_albums.csv')
df
# Out:
#                                            disco release_date  \
# 0                                   Taylor Swift   2006-10-24
# 1                                       Fearless   2008-11-11
# 2                     Speak Now (Deluxe Package)   2010-01-01
# 3                           Red (Deluxe Edition)   2012-10-22
# 4                                  1989 (Deluxe)   2014-01-01
# 5                                     reputation   2017-11-10
# 6                                          Lover   2019-08-23
# 7                      folklore (deluxe version)   2020-08-18
# 8                      evermore (deluxe version)   2021-01-07
# 9                        Midnights (3am Edition)   2022-10-22
# 10  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
#
#                                               markets  \
# 0   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 1                            [BE, CH, DE, ES, GR, SE]
# 2   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 3   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 4   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 5   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 6   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 7   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 8   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 9   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 10  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
#
#                        label  total_tracks
# 0            Universal Music            15
# 1   Big Machine Records, LLC            17
# 2   Big Machine Records, LLC            22
# 3   Big Machine Records, LLC            22
# 4   Big Machine Records, LLC            19
# 5   Big Machine Records, LLC            15
# 6               Taylor Swift            18
# 7               Taylor Swift            17
# 8                TS/Republic            17
# 9               Taylor Swift            20
# 10              Taylor Swift            31

# %%
lista_uri_tracks = []
track_info = {'name': [],
            'album': [],
            'release_date': [],
            'track_number': [],
            'id': [],
            'uri': []}

for disco in [lista_datos_discos[10]]:
    album_name = disco['name']
    track_info['album'].extend([album_name] * len(disco['tracks']['items']))

    album_date = disco['release_date']
    track_info['release_date'].extend([album_date] * len(disco['tracks']['items']))
    for track in disco['tracks']['items']:
        track_info['name'].append(track['name'])
        track_info['track_number'].append(track['track_number'])
        track_info['id'].append(track['id'])
        track_info['uri'].append(track['uri'])
        

track_info_df = pd.DataFrame(track_info)
track_info_df
# Out:
#                                          name  \
# 0               Fortnight (feat. Post Malone)
# 1               The Tortured Poets Department
# 2        My Boy Only Breaks His Favorite Toys
# 3                                    Down Bad
# 4                             So Long, London
# 5                        But Daddy I Love Him
# 6                       Fresh Out The Slammer
# 7   Florida!!! (feat. Florence + The Machine)
# 8                              Guilty as Sin?
# 9              Who’s Afraid of Little Old Me?
# 10            I Can Fix Him (No Really I Can)
# 11                                       loml
# 12            I Can Do It With a Broken Heart
# 13            The Smallest Man Who Ever Lived
# 14                                The Alchemy
# 15                                  Clara Bow
# 16                              The Black Dog
# 17                          imgonnagetyouback
# 18                              The Albatross
# 19           Chloe or Sam or Sophia or Marcus
# 20                            How Did It End?
# 21                             So High School
# 22                             I Hate It Here
# 23                            thanK you aIMee
# 24                 I Look in People's Windows
# 25                               The Prophecy
# 26                                  Cassandra
# 27                                      Peter
# 28                                 The Bolter
# 29                                      Robin
# 30                             The Manuscript
#
#                                            album release_date  track_number  \
# 0   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             1
# 1   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             2
# 2   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             3
# 3   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             4
# 4   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             5
# 5   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             6
# 6   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             7
# 7   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             8
# 8   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             9
# 9   THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            10
# 10  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            11
# 11  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            12
# 12  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            13
# 13  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            14
# 14  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            15
# 15  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            16
# 16  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            17
# 17  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            18
# 18  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            19
# 19  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            20
# 20  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            21
# 21  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            22
# 22  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            23
# 23  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            24
# 24  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            25
# 25  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            26
# 26  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            27
# 27  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            28
# 28  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            29
# 29  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            30
# 30  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19            31
#
#                         id                                   uri
# 0   6dODwocEuGzHAavXqTbwHv  spotify:track:6dODwocEuGzHAavXqTbwHv
# 1   4PdLaGZubp4lghChqp8erB  spotify:track:4PdLaGZubp4lghChqp8erB
# 2   7uGYWMwRy24dm7RUDDhUlD  spotify:track:7uGYWMwRy24dm7RUDDhUlD
# 3   1kbEbBdEgQdQeLXCJh28pJ  spotify:track:1kbEbBdEgQdQeLXCJh28pJ
# 4   7wAkQFShJ27V8362MqevQr  spotify:track:7wAkQFShJ27V8362MqevQr
# 5   4QMgEffJQuKtjCNvqfRZ0m  spotify:track:4QMgEffJQuKtjCNvqfRZ0m
# 6   7IWcDWOfiooH5hRs9XOVYz  spotify:track:7IWcDWOfiooH5hRs9XOVYz
# 7   5ExOm0dh4NyRyAdSAO9hyM  spotify:track:5ExOm0dh4NyRyAdSAO9hyM
# 8   799KrpEbhZp0MHeiA8YK9P  spotify:track:799KrpEbhZp0MHeiA8YK9P
# 9   2d8UxVNhJinc8uat9PoM9y  spotify:track:2d8UxVNhJinc8uat9PoM9y
# 10  5chnRTB9qMK3W1M41SnU9s  spotify:track:5chnRTB9qMK3W1M41SnU9s
# 11  3YkNIrAvbKNrrwwEd7NVLl  spotify:track:3YkNIrAvbKNrrwwEd7NVLl
# 12  2fPvQfGQEZOKtJ9qXeL4x8  spotify:track:2fPvQfGQEZOKtJ9qXeL4x8
# 13  1xtw1krCR6Dw2KwkXw5z63  spotify:track:1xtw1krCR6Dw2KwkXw5z63
# 14  1tuNqJOtRQVHvONR8Lg3MZ  spotify:track:1tuNqJOtRQVHvONR8Lg3MZ
# 15  4d9PtIEVij9jW5OaLinH66  spotify:track:4d9PtIEVij9jW5OaLinH66
# 16  62E2nR0od0M5HYxuYLaDz7  spotify:track:62E2nR0od0M5HYxuYLaDz7
# 17  1kcwpPDQnqEqmezzXdJTCP  spotify:track:1kcwpPDQnqEqmezzXdJTCP
# 18  4EF6IyONolQy0bIQXm2EmX  spotify:track:4EF6IyONolQy0bIQXm2EmX
# 19  1rmEsOezwf2lmIZTMAO5Ag  spotify:track:1rmEsOezwf2lmIZTMAO5Ag
# 20  5Bedn0svl0ZD7RGmJkmKKw  spotify:track:5Bedn0svl0ZD7RGmJkmKKw
# 21  7Mts0OfPorF4iwOomvfqn1  spotify:track:7Mts0OfPorF4iwOomvfqn1
# 22  3hlGuz3loYoLfI3bpwieWq  spotify:track:3hlGuz3loYoLfI3bpwieWq
# 23  7ogK4lJDVDMU6A6vYR5rvD  spotify:track:7ogK4lJDVDMU6A6vYR5rvD
# 24  1Zai5UJ2di3qEuR2HeT2s8  spotify:track:1Zai5UJ2di3qEuR2HeT2s8
# 25  18WFFUIsewmA8g31KAeo3e  spotify:track:18WFFUIsewmA8g31KAeo3e
# 26  0g4fMVo4JjwnIpTfFfLdxS  spotify:track:0g4fMVo4JjwnIpTfFfLdxS
# 27  3zMDGj4D8ogaYgAIZPeU7S  spotify:track:3zMDGj4D8ogaYgAIZPeU7S
# 28  2913xXOVAIDAqxzV2g4VcU  spotify:track:2913xXOVAIDAqxzV2g4VcU
# 29  2CnjDMdpRjlWv04Xk3s6MW  spotify:track:2CnjDMdpRjlWv04Xk3s6MW
# 30  1DTRUYVd8rYpla9hhVVwjo  spotify:track:1DTRUYVd8rYpla9hhVVwjo

# %%
track_audio_ft = {'uri': [],
            'acousticness': [],
            'danceability': [],
            'energy': [],
            'instrumentalness': [],
            'liveness': [],
            'loudness': [],
            'speechiness': [],
            'tempo': [],
            'valence': [],
            'popularity': [],
            'duration_ms': []
            }

for uri in track_info['uri']:
    datos = sp.audio_features(uri)
    track_audio_ft['uri'].append(datos[0]['uri'])
    track_audio_ft['acousticness'].append(datos[0]['acousticness'])
    track_audio_ft['danceability'].append(datos[0]['danceability'])
    track_audio_ft['energy'].append(datos[0]['energy'])
    track_audio_ft['instrumentalness'].append(datos[0]['instrumentalness'])
    track_audio_ft['liveness'].append(datos[0]['liveness'])
    track_audio_ft['loudness'].append(datos[0]['loudness'])
    track_audio_ft['speechiness'].append(datos[0]['speechiness'])
    track_audio_ft['tempo'].append(datos[0]['tempo'])
    track_audio_ft['valence'].append(datos[0]['valence'])
    track_audio_ft['duration_ms'].append(datos[0]['duration_ms'])

    track = sp.track(uri)
    track_audio_ft['popularity'].append(track["popularity"])


track_audio_ft_df =pd.DataFrame(track_audio_ft)
track_audio_ft_df
# Out:
#                                      uri  acousticness  danceability  energy  \
# 0   spotify:track:6dODwocEuGzHAavXqTbwHv        0.5340         0.670   0.395
# 1   spotify:track:4PdLaGZubp4lghChqp8erB        0.0522         0.604   0.435
# 2   spotify:track:7uGYWMwRy24dm7RUDDhUlD        0.1630         0.593   0.595
# 3   spotify:track:1kbEbBdEgQdQeLXCJh28pJ        0.5510         0.406   0.361
# 4   spotify:track:7wAkQFShJ27V8362MqevQr        0.7610         0.475   0.528
# 5   spotify:track:4QMgEffJQuKtjCNvqfRZ0m        0.3840         0.398   0.708
# 6   spotify:track:7IWcDWOfiooH5hRs9XOVYz        0.6220         0.328   0.491
# 7   spotify:track:5ExOm0dh4NyRyAdSAO9hyM        0.2100         0.526   0.565
# 8   spotify:track:799KrpEbhZp0MHeiA8YK9P        0.6120         0.627   0.422
# 9   spotify:track:2d8UxVNhJinc8uat9PoM9y        0.3260         0.603   0.359
# 10  spotify:track:5chnRTB9qMK3W1M41SnU9s        0.7900         0.665   0.252
# 11  spotify:track:3YkNIrAvbKNrrwwEd7NVLl        0.8690         0.369   0.267
# 12  spotify:track:2fPvQfGQEZOKtJ9qXeL4x8        0.1560         0.702   0.759
# 13  spotify:track:1xtw1krCR6Dw2KwkXw5z63        0.5280         0.420   0.405
# 14  spotify:track:1tuNqJOtRQVHvONR8Lg3MZ        0.4080         0.638   0.421
# 15  spotify:track:4d9PtIEVij9jW5OaLinH66        0.6620         0.673   0.334
# 16  spotify:track:62E2nR0od0M5HYxuYLaDz7        0.6750         0.533   0.292
# 17  spotify:track:1kcwpPDQnqEqmezzXdJTCP        0.6390         0.785   0.400
# 18  spotify:track:4EF6IyONolQy0bIQXm2EmX        0.6800         0.479   0.480
# 19  spotify:track:1rmEsOezwf2lmIZTMAO5Ag        0.7790         0.508   0.450
# 20  spotify:track:5Bedn0svl0ZD7RGmJkmKKw        0.7970         0.476   0.389
# 21  spotify:track:7Mts0OfPorF4iwOomvfqn1        0.0315         0.362   0.865
# 22  spotify:track:3hlGuz3loYoLfI3bpwieWq        0.7630         0.378   0.564
# 23  spotify:track:7ogK4lJDVDMU6A6vYR5rvD        0.6130         0.619   0.533
# 24  spotify:track:1Zai5UJ2di3qEuR2HeT2s8        0.6920         0.762   0.268
# 25  spotify:track:18WFFUIsewmA8g31KAeo3e        0.8280         0.434   0.520
# 26  spotify:track:0g4fMVo4JjwnIpTfFfLdxS        0.8200         0.582   0.599
# 27  spotify:track:3zMDGj4D8ogaYgAIZPeU7S        0.7670         0.348   0.394
# 28  spotify:track:2913xXOVAIDAqxzV2g4VcU        0.6000         0.447   0.588
# 29  spotify:track:2CnjDMdpRjlWv04Xk3s6MW        0.7750         0.462   0.381
# 30  spotify:track:1DTRUYVd8rYpla9hhVVwjo        0.8970         0.493   0.259
#
#     instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0           0.000007    0.0981   -10.924       0.0249   95.983    0.279
# 1           0.000003    0.1240    -8.377       0.0256  110.281    0.248
# 2           0.000000    0.2990    -7.348       0.0283   97.073    0.480
# 3           0.000000    0.0952   -10.296       0.1080  159.652    0.172
# 4           0.003500    0.0804   -11.452       0.2690  159.901    0.270
# 5           0.000000    0.1380    -7.629       0.1240   78.667    0.415
# 6           0.000000    0.1110    -9.361       0.0387   87.885    0.310
# 7           0.000000    0.3070    -7.090       0.1290  150.053    0.430
# 8           0.000000    0.0730    -8.331       0.0276   94.951    0.430
# 9           0.000000    0.1100   -10.513       0.0492  119.995    0.276
# 10          0.000000    0.1760   -13.961       0.0442  106.917    0.358
# 11          0.000000    0.1030   -12.561       0.0539   87.038    0.172
# 12          0.000000    0.1230    -8.292       0.0550  129.951    0.237
# 13          0.000000    0.3370    -9.042       0.0579  142.172    0.285
# 14          0.000000    0.1470    -8.655       0.0265  100.026    0.394
# 15          0.001690    0.1060   -10.990       0.0271  104.002    0.244
# 16          0.000000    0.1020   -10.630       0.0378  154.128    0.205
# 17          0.000000    0.1930    -9.401       0.0642  110.025    0.143
# 18          0.000000    0.0949    -8.889       0.0426  171.962    0.308
# 19          0.000000    0.1050    -8.495       0.0419   69.993    0.266
# 20          0.000915    0.1060    -8.886       0.0263   83.664    0.255
# 21          0.000003    0.1030    -4.577       0.0552  176.142    0.320
# 22          0.000000    0.3590    -7.107       0.0355  104.977    0.267
# 23          0.000000    0.1250    -7.994       0.0337   95.956    0.287
# 24          0.000000    0.1540   -11.429       0.0648   90.835    0.382
# 25          0.000002    0.2940   -10.279       0.0486  168.177    0.499
# 26          0.000000    0.1700    -9.811       0.0652  140.015    0.518
# 27          0.000000    0.0628    -8.258       0.0412  178.199    0.264
# 28          0.000000    0.1340    -7.950       0.0557  183.669    0.569
# 29          0.000516    0.1020   -10.548       0.0295  138.194    0.149
# 30          0.000004    0.1190   -11.743       0.0275   94.682    0.437
#
#     popularity  duration_ms
# 0           86       228965
# 1           84       293048
# 2           84       203801
# 3           84       261228
# 4           84       262975
# 5           84       340428
# 6           82       210789
# 7           83       215463
# 8           82       254366
# 9           83       334085
# 10          81       156298
# 11          82       277157
# 12          84       218005
# 13          82       245542
# 14          81       196900
# 15          81       216662
# 16          82       238857
# 17          82       222072
# 18          82       183879
# 19          81       213281
# 20          81       238707
# 21          82       228800
# 22          81       243876
# 23          82       263817
# 24          80       131907
# 25          81       249807
# 26          80       240206
# 27          80       283958
# 28          79       238242
# 29          78       240893
# 30          79       224744

# %%
df_merged = pd.merge(track_info_df, track_audio_ft_df, on='uri', how='left')
df_merged.head()
# Out:
#                                    name  \
# 0         Fortnight (feat. Post Malone)
# 1         The Tortured Poets Department
# 2  My Boy Only Breaks His Favorite Toys
# 3                              Down Bad
# 4                       So Long, London
#
#                                           album release_date  track_number  \
# 0  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             1
# 1  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             2
# 2  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             3
# 3  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             4
# 4  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19             5
#
#                        id                                   uri  acousticness  \
# 0  6dODwocEuGzHAavXqTbwHv  spotify:track:6dODwocEuGzHAavXqTbwHv        0.5340
# 1  4PdLaGZubp4lghChqp8erB  spotify:track:4PdLaGZubp4lghChqp8erB        0.0522
# 2  7uGYWMwRy24dm7RUDDhUlD  spotify:track:7uGYWMwRy24dm7RUDDhUlD        0.1630
# 3  1kbEbBdEgQdQeLXCJh28pJ  spotify:track:1kbEbBdEgQdQeLXCJh28pJ        0.5510
# 4  7wAkQFShJ27V8362MqevQr  spotify:track:7wAkQFShJ27V8362MqevQr        0.7610
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.670   0.395          0.000007    0.0981   -10.924       0.0249
# 1         0.604   0.435          0.000003    0.1240    -8.377       0.0256
# 2         0.593   0.595          0.000000    0.2990    -7.348       0.0283
# 3         0.406   0.361          0.000000    0.0952   -10.296       0.1080
# 4         0.475   0.528          0.003500    0.0804   -11.452       0.2690
#
#      tempo  valence  popularity  duration_ms
# 0   95.983    0.279          86       228965
# 1  110.281    0.248          84       293048
# 2   97.073    0.480          84       203801
# 3  159.652    0.172          84       261228
# 4  159.901    0.270          84       262975

# %%
df_merged.to_csv('files/ts_spotify_fearless-red-ttpd.csv', index=False)

# %%
df_merged['album'].unique()
# Out:
# array(['Fearless', 'Red (Deluxe Edition)',
#        'THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY'], dtype=object)

# %% [markdown]
# # MERGE ALL ALBUMS

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_16432\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_ts_spotify1 = pd.read_csv('files/taylor_swift_spotify.csv', index_col=0)
df_ts_spotify2 = pd.read_csv('files/ts_spotify_fearless-red-ttpd.csv')

# %%
display(df_ts_spotify1.head())
display(df_ts_spotify2.head())
# Out:
#                                             name  \
# 0         Welcome To New York (Taylor's Version)
# 1                 Blank Space (Taylor's Version)
# 2                       Style (Taylor's Version)
# 3            Out Of The Woods (Taylor's Version)
# 4  All You Had To Do Was Stay (Taylor's Version)
#
#                               album release_date  track_number  \
# 0  1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1  1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2  1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3  1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4  1989 (Taylor's Version) [Deluxe]   2023-10-27             5
#
#                        id                                   uri  acousticness  \
# 0  4WUepByoeqcedHoYhSNHRt  spotify:track:4WUepByoeqcedHoYhSNHRt      0.009420
# 1  0108kcWLnn2HlH2kedi1gn  spotify:track:0108kcWLnn2HlH2kedi1gn      0.088500
# 2  3Vpk1hfMAQme8VJ0SNRSkd  spotify:track:3Vpk1hfMAQme8VJ0SNRSkd      0.000421
# 3  1OcSfkeCg9hRC2sFKB4IMJ  spotify:track:1OcSfkeCg9hRC2sFKB4IMJ      0.000537
# 4  2k0ZEeAqzvYMcx9Qt5aClQ  spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ      0.000656
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.757   0.610          0.000037    0.3670    -4.840       0.0327
# 1         0.733   0.733          0.000000    0.1680    -5.376       0.0670
# 2         0.511   0.822          0.019700    0.0899    -4.785       0.0397
# 3         0.545   0.885          0.000056    0.3850    -5.968       0.0447
# 4         0.588   0.721          0.000000    0.1310    -5.579       0.0317
#
#      tempo  valence  popularity  duration_ms
# 0  116.998    0.685          66       212600
# 1   96.057    0.701          67       231833
# 2   94.868    0.305          68       231000
# 3   92.021    0.206          67       235800
# 4   96.997    0.520          65       193289
#           name     album  track_number                      id  \
# 0     Fearless  Fearless             1  4lIbdZwGa2hgkxigHJumaV
# 1      Fifteen  Fearless             2  2l9Pipz6AiVOabtKJVl3O9
# 2   Love Story  Fearless             3  0wi9VaczZO8tbBwltGiwO5
# 3  Hey Stephen  Fearless             4  4vwfVWo6hSf0vJuBpNwMWJ
# 4  White Horse  Fearless             5  04g3rUk3RzqaXi02FJT2Zl
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:4lIbdZwGa2hgkxigHJumaV        0.0393         0.403   0.699
# 1  spotify:track:2l9Pipz6AiVOabtKJVl3O9        0.0665         0.558   0.634
# 2  spotify:track:0wi9VaczZO8tbBwltGiwO5        0.0198         0.618   0.637
# 3  spotify:track:4vwfVWo6hSf0vJuBpNwMWJ        0.1810         0.841   0.543
# 4  spotify:track:04g3rUk3RzqaXi02FJT2Zl        0.2720         0.582   0.334
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000    0.3030    -4.412       0.0352  200.056    0.448
# 1          0.000000    0.1450    -4.437       0.0267   95.349    0.208
# 2          0.000080    0.1690    -5.412       0.0289  119.056    0.269
# 3          0.000002    0.0903    -7.338       0.0315  115.994    0.827
# 4          0.000000    0.1020    -8.035       0.0260   92.710    0.231
#
#    popularity  duration_ms
# 0          28       243400
# 1          24       295213
# 2          35       234707
# 3          23       256053
# 4          24       235427

# %%
df_ts_spotify1['album'].unique()
# Out:
# array(["1989 (Taylor's Version) [Deluxe]", "1989 (Taylor's Version)",
#        "Speak Now (Taylor's Version)", 'Midnights (The Til Dawn Edition)',
#        'Midnights (3am Edition)', 'Midnights', "Red (Taylor's Version)",
#        "Fearless (Taylor's Version)", 'evermore (deluxe version)',
#        'evermore',
#        'folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]',
#        'folklore (deluxe version)', 'folklore', 'Lover', 'reputation',
#        'reputation Stadium Tour Surprise Song Playlist',
#        '1989 (Deluxe Edition)', '1989', 'Red (Deluxe Edition)', 'Red',
#        'Speak Now World Tour Live', 'Speak Now (Deluxe Edition)',
#        'Speak Now', 'Fearless Platinum Edition', 'Fearless',
#        'Live From Clear Channel Stripped 2008', 'Taylor Swift'],
#       dtype=object)

# %%
albumes = ['Taylor Swift',
            'Fearless Platinum Edition',
            'Speak Now (Deluxe Edition)',
            'Red (Deluxe Edition)',
            '1989 (Deluxe Edition)',
            'reputation',
            'Lover',
            'folklore (deluxe version)',
            'evermore (deluxe version)',
            'Midnights (3am Edition)']

# %%
df_ts_spotify1.head()
# Out:
#                                             name  \
# 0         Welcome To New York (Taylor's Version)
# 1                 Blank Space (Taylor's Version)
# 2                       Style (Taylor's Version)
# 3            Out Of The Woods (Taylor's Version)
# 4  All You Had To Do Was Stay (Taylor's Version)
#
#                               album release_date  track_number  \
# 0  1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1  1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2  1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3  1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4  1989 (Taylor's Version) [Deluxe]   2023-10-27             5
#
#                        id                                   uri  acousticness  \
# 0  4WUepByoeqcedHoYhSNHRt  spotify:track:4WUepByoeqcedHoYhSNHRt      0.009420
# 1  0108kcWLnn2HlH2kedi1gn  spotify:track:0108kcWLnn2HlH2kedi1gn      0.088500
# 2  3Vpk1hfMAQme8VJ0SNRSkd  spotify:track:3Vpk1hfMAQme8VJ0SNRSkd      0.000421
# 3  1OcSfkeCg9hRC2sFKB4IMJ  spotify:track:1OcSfkeCg9hRC2sFKB4IMJ      0.000537
# 4  2k0ZEeAqzvYMcx9Qt5aClQ  spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ      0.000656
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.757   0.610          0.000037    0.3670    -4.840       0.0327
# 1         0.733   0.733          0.000000    0.1680    -5.376       0.0670
# 2         0.511   0.822          0.019700    0.0899    -4.785       0.0397
# 3         0.545   0.885          0.000056    0.3850    -5.968       0.0447
# 4         0.588   0.721          0.000000    0.1310    -5.579       0.0317
#
#      tempo  valence  popularity  duration_ms
# 0  116.998    0.685          66       212600
# 1   96.057    0.701          67       231833
# 2   94.868    0.305          68       231000
# 3   92.021    0.206          67       235800
# 4   96.997    0.520          65       193289

# %%
df_spotify = df_ts_spotify1[df_ts_spotify1['album'].isin(albumes)].reset_index(drop=True)
df_spotify.head()
# Out:
#                                      name                    album  \
# 0                           Lavender Haze  Midnights (3am Edition)
# 1                                  Maroon  Midnights (3am Edition)
# 2                               Anti-Hero  Midnights (3am Edition)
# 3  Snow On The Beach (feat. Lana Del Rey)  Midnights (3am Edition)
# 4                 You're On Your Own, Kid  Midnights (3am Edition)
#
#   release_date  track_number                      id  \
# 0   2022-10-22             1  4g2c7NoTWAOSYDy44l9nub
# 1   2022-10-22             2  199E1RRrVmVTQqBXih5qRC
# 2   2022-10-22             3  02Zkkf2zMkwRGQjZ7T4p8f
# 3   2022-10-22             4  6ADDIJxxqzM9LMpm78yzQG
# 4   2022-10-22             5  7gVWKBcfIW93YxNBi3ApIE
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:4g2c7NoTWAOSYDy44l9nub        0.2040         0.735   0.444
# 1  spotify:track:199E1RRrVmVTQqBXih5qRC        0.0593         0.658   0.378
# 2  spotify:track:02Zkkf2zMkwRGQjZ7T4p8f        0.1330         0.638   0.634
# 3  spotify:track:6ADDIJxxqzM9LMpm78yzQG        0.7350         0.659   0.323
# 4  spotify:track:7gVWKBcfIW93YxNBi3ApIE        0.4160         0.694   0.380
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.001200    0.1700   -10.519       0.0684   97.038   0.0984
# 1          0.000000    0.0976    -8.300       0.0379  108.034   0.0382
# 2          0.000001    0.1520    -6.582       0.0457   96.953   0.5190
# 3          0.003210    0.1160   -13.425       0.0436  110.007   0.1540
# 4          0.000008    0.1260   -10.307       0.0614  120.044   0.3760
#
#    popularity  duration_ms
# 0          65       202395
# 1          65       218270
# 2          66       200690
# 3          65       256124
# 4          66       194206

# %%
df_concatenado = pd.concat([df_spotify, df_merged], ignore_index=True)

df_concatenado.head()
# Out:
#                                      name                    album  \
# 0                           Lavender Haze  Midnights (3am Edition)
# 1                                  Maroon  Midnights (3am Edition)
# 2                               Anti-Hero  Midnights (3am Edition)
# 3  Snow On The Beach (feat. Lana Del Rey)  Midnights (3am Edition)
# 4                 You're On Your Own, Kid  Midnights (3am Edition)
#
#   release_date  track_number                      id  \
# 0   2022-10-22             1  4g2c7NoTWAOSYDy44l9nub
# 1   2022-10-22             2  199E1RRrVmVTQqBXih5qRC
# 2   2022-10-22             3  02Zkkf2zMkwRGQjZ7T4p8f
# 3   2022-10-22             4  6ADDIJxxqzM9LMpm78yzQG
# 4   2022-10-22             5  7gVWKBcfIW93YxNBi3ApIE
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:4g2c7NoTWAOSYDy44l9nub        0.2040         0.735   0.444
# 1  spotify:track:199E1RRrVmVTQqBXih5qRC        0.0593         0.658   0.378
# 2  spotify:track:02Zkkf2zMkwRGQjZ7T4p8f        0.1330         0.638   0.634
# 3  spotify:track:6ADDIJxxqzM9LMpm78yzQG        0.7350         0.659   0.323
# 4  spotify:track:7gVWKBcfIW93YxNBi3ApIE        0.4160         0.694   0.380
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.001200    0.1700   -10.519       0.0684   97.038   0.0984
# 1          0.000000    0.0976    -8.300       0.0379  108.034   0.0382
# 2          0.000001    0.1520    -6.582       0.0457   96.953   0.5190
# 3          0.003210    0.1160   -13.425       0.0436  110.007   0.1540
# 4          0.000008    0.1260   -10.307       0.0614  120.044   0.3760
#
#    popularity  duration_ms
# 0          65       202395
# 1          65       218270
# 2          66       200690
# 3          65       256124
# 4          66       194206

# %%
df_concatenado.to_csv('files/all_songs_audio_data.csv')

# %% [markdown]
# # INFO DE ALBUM

# %%
import pandas as pd

from bs4 import BeautifulSoup
import requests

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.support.ui import Select 

from time import sleep

pd.set_option('display.max_columns', None)

# %%
data_album = {'album': [],
                'sales': [],
                'awards': [],
                'score_critic': [],
                'score_public': []}

# %%
driver = webdriver.Chrome()
driver.get('https://en.wikipedia.org/wiki/Taylor_Swift_albums_discography')
sleep(1)
for child in range(3, 13):
    data_album['album'].append(driver.find_element('css selector', f'#mw-content-text > div.mw-content-ltr.mw-parser-output > table:nth-child(13) > tbody > tr:nth-child({child}) > th').text)
    data_album['sales'].append((driver.find_element('css selector', f'#mw-content-text > div.mw-content-ltr.mw-parser-output > table:nth-child(13) > tbody > tr:nth-child({child}) > td:nth-child(13)').text).split('\n')[0])

data_album
# Out:
# {'album': ['Taylor Swift',
#   'Fearless',
#   'Speak Now',
#   'Red',
#   '1989',
#   'Reputation',
#   'Lover',
#   'Folklore',
#   'Evermore',
#   'Midnights'],
#  'sales': ['US: 5,871,000[B]',
#   'US: 7,286,000[D]',
#   'US: 4,817,000[B]',
#   'US: 4,582,000[B]',
#   'US: 6,472,000[B]',
#   'US: 2,478,000[B]',
#   'US: 2,000,000[D]',
#   'US: 2,289,000[B]',
#   'US: 913,000[H]',
#   'US: 2,814,000[B]'],
#  'awards': [],
#  'score_critic': [],
#  'score_public': []}

# %%
driver = webdriver.Chrome()

# no voy a poner el último aquí porque hay aún pocas reviews aún
for disco in ['taylor-swift', 'fearless', 'speak-now', 'red', '1989', 'reputation', 'lover', 'folklore', 'evermore', 'midnights']:
    url = f'https://www.metacritic.com/music/{disco}/taylor-swift'
    driver.get(url)
    sleep(1)

    data_album['score_critic'].append(driver.find_element('css selector', '#main > div:nth-child(2) > div:nth-child(1) > div.left > div.module.product_data.product_data_summary > div > div.summary_wrap > div.section.product_scores > div.details.main_details > div > div > a > div').text)
    data_album['score_public'].append(driver.find_element('css selector', '#main > div:nth-child(2) > div:nth-child(1) > div.left > div.module.product_data.product_data_summary > div > div.summary_wrap > div.section.product_scores > div.details.side_details > div > div > a > div').text)

# %%
data_album_df = pd.DataFrame(data_album)

data_album_df.to_csv('files/album_info.csv')

# %% [markdown]
# # SCRAPEO LETRAS

# %%
lyrics = {'song':[], 'lyrics': []}

# %%
driver = webdriver.Chrome()

canciones = [
    'Fortnight',
    'The Tortured Poets Department',
    'My Boy Only Breaks His Favorite Toys',
    'Down Bad',
    'So Long, London',
    'But Daddy I Love Him',
    'Fresh Out The Slammer',
    'Florida!!!',
    'Guilty as Sin?',
    "Who's Afraid of Little Old Me?",
    'I Can Fix Him (No Really I Can)',
    'loml',
    'I Can Do It With A Broken Heart',
    'The Smallest Man Who Ever Lived',
    'The Alchemy',
    'Clara Bow',
    'The Black Dog',
    'imgonnagetyouback',
    'The Albatross',
    'Chloe or Sam or Sophia or Marcus',
    'How Did it End?',
    'So High School',
    'I Hate it Here',
    'thanK you aiMee',
    'I Look in Peoples Windows',
    'The Prophecy',
    'Cassandra',
    'Peter',
    'The Bolter',
    'Robin',
    'Tha Manuscript'           
    ]

canciones_mod = [
    'fortnight',
    'the-tortured-poets-department',
    'my-boy-only-breaks-his-favorite-toys',
    'down-bad',
    'so-long-london',
    'but-daddy-i-love-him',
    'fresh-out-the-slammer',
    'florida',
    'guilty-as-sin',
    'whos-afraid-of-little-old-me',
    'i-can-fix-him-no-really-i-can',
    'loml',
    'i-can-do-it-with-a-broken-heart',
    'the-smallest-man-who-ever-lived',
    'the-alchemy',
    'clara-bow',
    'the-black-dog',
    'imgonnagetyouback',
    'the-albatross',
    'chloe-or-sam-or-sophia-or-marcus',
    'how-did-it-end',
    'so-high-school',
    'i-hate-it-here',
    'thank-you-aimee',
    'i-look-in-peoples-windows',
    'the-prophecy',
    'cassandra',
    'peter',
    'the-bolter',
    'robin',
    'tha-manuscript'
]

for cancion, cancion_mod in zip(canciones, canciones_mod):
    
    driver.get(f'https://genius.com/Taylor-swift-{cancion_mod}-lyrics')

    # cookies
    try:
        driver.find_element('css selector', '#onetrust-accept-btn-handler').click()
    except:
        pass
    
    # Añade el título de la canción
    lyrics['lyrics'].append(cancion)
    
    # lyrics
    lyrics['lyrics'].append(driver.find_element('css selector', '#lyrics-root > div:nth-child(2)').text)
    
    sleep(3)

# %% [markdown]
# # TOURS (KAGGLE)

# %%
df_conciertos = pd.read_csv('files/Taylor_Train.csv', encoding='ISO-8859-1')
df_conciertos
# Out:
#      Unnamed: 0              City        Country                      Venue  \
# 0             0        Evansville  United States  Roberts Municipal Stadium
# 1             1         Jonesboro  United States         Convocation Center
# 2             2         St. Louis  United States           Scottrade Center
# 3             3        Alexandria  United States  Bishop Ireton High School
# 4             4  North Charleston  United States  North Charleston Coliseum
# ..          ...               ...            ...                        ...
# 440         440            Sydney      Australia                ANZ Stadium
# 441         441          Brisbane      Australia                  The Gabba
# 442         442          Auckland    New Zealand        Mount Smart Stadium
# 443         443             Tokyo          Japan                 Tokyo Dome
# 444         444             Tokyo          Japan                 Tokyo Dome
#
#                  Opening act(s) Attendance (tickets sold / available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                    Â
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#          Revenue        Tour
# 0       $360,617    fearless
# 1       $340,328    fearless
# 2       $650,420    fearless
# 3             Â    fearless
# 4       $398,154    fearless
# ..           ...         ...
# 440   $7,686,564  reputation
# 441   $4,338,127  reputation
# 442   $3,617,593  reputation
# 443  $14,859,847  reputation
# 444  $14,859,847  reputation
#
# [445 rows x 8 columns]

# %%
df_conciertos['Tour'] = df_conciertos['Tour'].map({'Fearless_Tour': 'fearless', 'Speak_Now_World_Tour': 'speak now', 'The_Red_Tour': 'red', 'The_1989_World_Tour': '1989', 'Reputation_Stadium_Tour': 'reputation'})

# %%
def tour_id(valor):
    if valor == 'fearless':
        return 'ts02'
    elif valor == 'speak now':
        return 'ts03'
    elif valor == 'red':
        return 'ts04'
    elif valor == '1989':
        return 'ts05'
    elif valor == 'reputation':
        return 'ts06'

# %%
df_conciertos['tour_id'] = df_conciertos['Tour'].apply(tour_id)
df_conciertos
# Out:
#      Unnamed: 0              City        Country                      Venue  \
# 0             0        Evansville  United States  Roberts Municipal Stadium
# 1             1         Jonesboro  United States         Convocation Center
# 2             2         St. Louis  United States           Scottrade Center
# 3             3        Alexandria  United States  Bishop Ireton High School
# 4             4  North Charleston  United States  North Charleston Coliseum
# ..          ...               ...            ...                        ...
# 440         440            Sydney      Australia                ANZ Stadium
# 441         441          Brisbane      Australia                  The Gabba
# 442         442          Auckland    New Zealand        Mount Smart Stadium
# 443         443             Tokyo          Japan                 Tokyo Dome
# 444         444             Tokyo          Japan                 Tokyo Dome
#
#                  Opening act(s) Attendance (tickets sold / available)  \
# 0    Gloriana\r\nKellie Pickler                         7,463 / 7,463
# 1    Gloriana\r\nKellie Pickler                         7,822 / 7,822
# 2    Gloriana\r\nKellie Pickler                       13,764 / 13,764
# 3    Gloriana\r\nKellie Pickler                                    Â
# 4    Gloriana\r\nKellie Pickler                         8,751 / 8,751
# ..                          ...                                   ...
# 440        Charli XCX\r\nBroods                       72,805 / 72,805
# 441        Charli XCX\r\nBroods                       43,907 / 43,907
# 442        Charli XCX\r\nBroods                       35,749 / 35,749
# 443                  Charli XCX                     100,109 / 100,109
# 444                  Charli XCX                     100,109 / 100,109
#
#          Revenue        Tour tour_id
# 0       $360,617    fearless    ts02
# 1       $340,328    fearless    ts02
# 2       $650,420    fearless    ts02
# 3             Â    fearless    ts02
# 4       $398,154    fearless    ts02
# ..           ...         ...     ...
# 440   $7,686,564  reputation    ts06
# 441   $4,338,127  reputation    ts06
# 442   $3,617,593  reputation    ts06
# 443  $14,859,847  reputation    ts06
# 444  $14,859,847  reputation    ts06
#
# [445 rows x 9 columns]

# %%
df_conciertos.to_csv('files/concerts_per_tour.csv', index=False)

# %% [markdown]
# # EDITAR DATASETS

# %%
album_info = pd.read_csv('files/album_info.csv', index_col=0)

# %%
album_info['tour_revenue'] = ('No Tour', 66246496, 123678576, 150184971, 250733097, 345675146, 'No Tour', 'No Tour', 'No Tour', 'No Tour')
album_info
# Out:
#           album             sales  score_critic  score_public tour_revenue
# 0  Taylor Swift  US: 5,871,000[B]            67           8.4      No Tour
# 1      Fearless  US: 7,286,000[D]            73           8.4     66246496
# 2     Speak Now  US: 4,817,000[B]            77           8.6    123678576
# 3           Red  US: 4,582,000[B]            77           8.6    150184971
# 4          1989  US: 6,472,000[B]            76           8.3    250733097
# 5    Reputation  US: 2,478,000[B]            71           8.3    345675146
# 6         Lover  US: 2,000,000[D]            79           8.4      No Tour
# 7      Folklore  US: 2,289,000[B]            88           9.0      No Tour
# 8      Evermore    US: 913,000[H]            85           8.9      No Tour
# 9     Midnights  US: 2,814,000[B]            85           8.3      No Tour

# %%
album_info['sales'] = album_info['sales'].apply(lambda x : int(x.replace(',', '').replace('[B]', '').replace('[D]', '').replace('[H]', '').replace('US:', '').strip()))
album_info['tour_id'] = ['No Tour', 'ts02', 'ts03', 'ts04', 'ts05', 'ts06', 'No Tour', 'No Tour', 'No Tour', 'No Tour']
album_info
# Out:
#           album  sales (US)  score_critic  score_public tour_revenue ($)  \
# 0  Taylor Swift     5871000            67           8.4          No Tour
# 1      Fearless     7286000            73           8.4         66246496
# 2     Speak Now     4817000            77           8.6        123678576
# 3           Red     4582000            77           8.6        150184971
# 4          1989     6472000            76           8.3        250733097
# 5    Reputation     2478000            71           8.3        345675146
# 6         Lover     2000000            79           8.4          No Tour
# 7      Folklore     2289000            88           9.0          No Tour
# 8      Evermore      913000            85           8.9          No Tour
# 9     Midnights     2814000            85           8.3          No Tour
#
#    tour_id
# 0  No Tour
# 1     ts02
# 2     ts03
# 3     ts04
# 4     ts05
# 5     ts06
# 6  No Tour
# 7  No Tour
# 8  No Tour
# 9  No Tour

# %%
album_info.to_csv('files/album_info.csv', index=False)
