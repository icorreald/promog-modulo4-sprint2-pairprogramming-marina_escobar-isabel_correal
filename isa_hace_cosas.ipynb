# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np

from src import api_soporte as api

# %%
sp = api.credenciales()

# %%
lista_discos = ['https://open.spotify.com/album/5eyZZoQEFQWRHkV2xgAeBw?si=QfZUzkisSweWF6f5Zw48SQ', # debut
                'https://open.spotify.com/album/6tgMb6LEwb3yj7BdYy462y?si=KMuHR1gFSUabKJnnBBpmfA', # fearless
                'https://open.spotify.com/album/6S6JQWzUrJVcJLK4fi74Fw?si=Y28PyIx-S2KlQj7MHk11TA', # speak now (deluxe)
                'https://open.spotify.com/intl-es/album/1KVKqWeRuXsJDLTW0VuD29?si=4ObfYoNORsaeV85ZUdfxZw', # red
                'https://open.spotify.com/album/1yGbNOtRIgdIiGHOEBaZWf?si=cQmUCtaYTq2MXY-G9jA8-Q', # 1989 deluxe
                'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv?si=XTd1zjmRSI-yMgw9tB1Stg', # reputa
                'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq?si=VyPthD5zR5yqq27y4qgUyw', # lover
                'https://open.spotify.com/album/1pzvBxYgT6OVwJLtHkrdQK?si=KtiGk4TYQCapyGHhnZwavA', # folklore
                'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG?si=hcY11QxLR4OX8LDkNVtwOw', # evermore
                'https://open.spotify.com/album/3lS1y25WAhcqJDATJK70Mq?si=XPoxfq8iTU6GVBKZK9sMfg', # midnights (3am)
                'https://open.spotify.com/album/5H7ixXZfsNMGbIE5OBSpcb?si=idsuy6fzS0GIUdFBYqOKGQ'] # ttpd (2am)

lista_uri = []
for link in lista_discos:
    lista_uri.append(link.split('/')[-1].split('?')[0])

lista_uri
# Out:
# ['5eyZZoQEFQWRHkV2xgAeBw',
#  '6tgMb6LEwb3yj7BdYy462y',
#  '6S6JQWzUrJVcJLK4fi74Fw',
#  '1KVKqWeRuXsJDLTW0VuD29',
#  '1yGbNOtRIgdIiGHOEBaZWf',
#  '6DEjYFkNZh67HP7R9PSZvv',
#  '1NAmidJlEaVgA3MpcPFYGq',
#  '1pzvBxYgT6OVwJLtHkrdQK',
#  '6AORtDjduMM3bupSWzbTSG',
#  '3lS1y25WAhcqJDATJK70Mq',
#  '5H7ixXZfsNMGbIE5OBSpcb']

# %%
lista_datos_discos = []
for uri in lista_uri:
    lista_datos_discos.append(sp.album(uri))
lista_datos_discos
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'GB',
#    'ID',
#    'JP',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LR',
#    'MW',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'AZ',
#    'BN',
#    'BI',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GN',
#    'KG',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'ZM',
#    'CD',
#    'CG',
#    'TJ',
#    'VE',
#    'XK'],
#   'copyrights': [{'text': '© 2008 Apollo A-1 LLC', 'type': 'C'},
#    {'text': '℗ 2008 Apollo A-1 LLC', 'type': 'P'}],
#   'external_ids': {'upc': '00602517874695'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5eyZZoQEFQWRHkV2xgAeBw'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/5eyZZoQEFQWRHkV2xgAeBw',
#   'id': '5eyZZoQEFQWRHkV2xgAeBw',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c909d4e47de2ab0636f46d64',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c909d4e47de2ab0636f46d64',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c909d4e47de2ab0636f46d64',
#     'width': 64}],
#   'label': 'Universal Music',
#   'name': 'Taylor Swift',
#   'popularity': 74,
#   'release_date': '2006-10-24',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/5eyZZoQEFQWRHkV2xgAeBw/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 232106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2Fn01AIMyHbha2ceNQeOqw'},
#      'href': 'https://api.spotify.com/v1/tracks/2Fn01AIMyHbha2ceNQeOqw',
#      'id': '2Fn01AIMyHbha2ceNQeOqw',
#      'is_local': False,
#      'name': 'Tim McGraw',
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2Fn01AIMyHbha2ceNQeOqw'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 173066,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4BYejINgfZF0qKDMEH2cim'},
#      'href': 'https://api.spotify.com/v1/tracks/4BYejINgfZF0qKDMEH2cim',
#      'id': '4BYejINgfZF0qKDMEH2cim',
#      'is_local': False,
#      'name': 'Picture To Burn',
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:4BYejINgfZF0qKDMEH2cim'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 203040,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2TF4UtYreqNbQ6Z9AccldU'},
#      'href': 'https://api.spotify.com/v1/tracks/2TF4UtYreqNbQ6Z9AccldU',
#      'id': '2TF4UtYreqNbQ6Z9AccldU',
#      'is_local': False,
#      'name': 'Teardrops On My Guitar - Radio Single Remix',
#      'preview_url': None,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:2TF4UtYreqNbQ6Z9AccldU'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 199200,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1oR4MUBpyNrAViC8wPNpfm'},
#      'href': 'https://api.spotify.com/v1/tracks/1oR4MUBpyNrAViC8wPNpfm',
#      'id': '1oR4MUBpyNrAViC8wPNpfm',
#      'is_local': False,
#      'name': 'A Place in this World',
#      'preview_url': None,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:1oR4MUBpyNrAViC8wPNpfm'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 239013,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/569sXXQ7t0jSdqHooi2yqs'},
#      'href': 'https://api.spotify.com/v1/tracks/569sXXQ7t0jSdqHooi2yqs',
#      'id': '569sXXQ7t0jSdqHooi2yqs',
#      'is_local': False,
#      'name': 'Cold As You',
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:569sXXQ7t0jSdqHooi2yqs'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 207106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5Tj2MqcFMf60CaGsKbM1aq'},
#      'href': 'https://api.spotify.com/v1/tracks/5Tj2MqcFMf60CaGsKbM1aq',
#      'id': '5Tj2MqcFMf60CaGsKbM1aq',
#      'is_local': False,
#      'name': 'The Outside',
#      'preview_url': None,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5Tj2MqcFMf60CaGsKbM1aq'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 248106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2zzxwmoOBnXDT0KnJsoIWk'},
#      'href': 'https://api.spotify.com/v1/tracks/2zzxwmoOBnXDT0KnJsoIWk',
#      'id': '2zzxwmoOBnXDT0KnJsoIWk',
#      'is_local': False,
#      'name': 'Tied Together with a Smile',
#      'preview_url': None,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:2zzxwmoOBnXDT0KnJsoIWk'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 236053,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/41sjzdjScVwnxnxADElts6'},
#      'href': 'https://api.spotify.com/v1/tracks/41sjzdjScVwnxnxADElts6',
#      'id': '41sjzdjScVwnxnxADElts6',
#      'is_local': False,
#      'name': 'Stay Beautiful',
#      'preview_url': None,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:41sjzdjScVwnxnxADElts6'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 242200,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6CdaXOq1MWe2JHDalTG01d'},
#      'href': 'https://api.spotify.com/v1/tracks/6CdaXOq1MWe2JHDalTG01d',
#      'id': '6CdaXOq1MWe2JHDalTG01d',
#      'is_local': False,
#      'name': "Should've Said No",
#      'preview_url': None,
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:6CdaXOq1MWe2JHDalTG01d'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 213080,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2O8sogKJCfVZ4rotBv1vVF'},
#      'href': 'https://api.spotify.com/v1/tracks/2O8sogKJCfVZ4rotBv1vVF',
#      'id': '2O8sogKJCfVZ4rotBv1vVF',
#      'is_local': False,
#      'name': "Mary's Song (Oh My My My)",
#      'preview_url': None,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:2O8sogKJCfVZ4rotBv1vVF'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 201106,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1j6gmK6u4WNI33lMZ8dC1s'},
#      'href': 'https://api.spotify.com/v1/tracks/1j6gmK6u4WNI33lMZ8dC1s',
#      'id': '1j6gmK6u4WNI33lMZ8dC1s',
#      'is_local': False,
#      'name': 'Our Song',
#      'preview_url': None,
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:1j6gmK6u4WNI33lMZ8dC1s'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 213053,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7CzxXgQXurKZCyHz9ufbo1'},
#      'href': 'https://api.spotify.com/v1/tracks/7CzxXgQXurKZCyHz9ufbo1',
#      'id': '7CzxXgQXurKZCyHz9ufbo1',
#      'is_local': False,
#      'name': "I'm Only Me When I'm With You",
#      'preview_url': None,
#      'track_number': 12,
#      'type': 'track',
#      'uri': 'spotify:track:7CzxXgQXurKZCyHz9ufbo1'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 203226,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1k3PzDNjg38cWqOvL4M9vq'},
#      'href': 'https://api.spotify.com/v1/tracks/1k3PzDNjg38cWqOvL4M9vq',
#      'id': '1k3PzDNjg38cWqOvL4M9vq',
#      'is_local': False,
#      'name': 'Invisible',
#      'preview_url': None,
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:1k3PzDNjg38cWqOvL4M9vq'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 220146,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0YgHuReCSPwTXYny7isLja'},
#      'href': 'https://api.spotify.com/v1/tracks/0YgHuReCSPwTXYny7isLja',
#      'id': '0YgHuReCSPwTXYny7isLja',
#      'is_local': False,
#      'name': 'A Perfectly Good Heart',
#      'preview_url': None,
#      'track_number': 14,
#      'type': 'track',
#      'uri': 'spotify:track:0YgHuReCSPwTXYny7isLja'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'ID',
#       'JP',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GN',
#       'KG',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'ZM',
#       'CD',
#       'CG',
#       'TJ',
#       'VE',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 179066,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1hxLyjC9D9Jpw6EAPKqWv4'},
#      'href': 'https://api.spotify.com/v1/tracks/1hxLyjC9D9Jpw6EAPKqWv4',
#      'id': '1hxLyjC9D9Jpw6EAPKqWv4',
#      'is_local': False,
#      'name': 'Teardrops on My Guitar - Pop Version',
#      'preview_url': None,
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1hxLyjC9D9Jpw6EAPKqWv4'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 15},
#   'type': 'album',
#   'uri': 'spotify:album:5eyZZoQEFQWRHkV2xgAeBw'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#   'copyrights': [{'text': '© 2009 Apollo A-1 LLC', 'type': 'C'},
#    {'text': '℗ 2009 Apollo A-1 LLC', 'type': 'P'}],
#   'external_ids': {'upc': '00602517999381'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6tgMb6LEwb3yj7BdYy462y'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/6tgMb6LEwb3yj7BdYy462y',
#   'id': '6tgMb6LEwb3yj7BdYy462y',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736ff72554305455511e786687',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026ff72554305455511e786687',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516ff72554305455511e786687',
#     'width': 64}],
#   'label': 'Big Machine Records, LLC',
#   'name': 'Fearless',
#   'popularity': 40,
#   'release_date': '2008-11-11',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/6tgMb6LEwb3yj7BdYy462y/tracks?offset=0&limit=50',
#    'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#      'disc_number': 1,
#      'duration_ms': 243400,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4lIbdZwGa2hgkxigHJumaV'},
#      'href': 'https://api.spotify.com/v1/tracks/4lIbdZwGa2hgkxigHJumaV',
#      'id': '4lIbdZwGa2hgkxigHJumaV',
#      'is_local': False,
#      'name': 'Fearless',
#      'preview_url': None,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:4lIbdZwGa2hgkxigHJumaV'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['BE', 'CH', 'DE', 'ES', 'GR', 'SE'],
#      'disc_number': 1,
#      'duration_ms': 295213,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2l9Pipz6AiVOabtKJVl3O9'},
#      'href': 'https://api.spotify.com/v1/tracks/2l9Pipz6AiVOabtKJVl3O9',
#      'id': '2l9Pipz6AiVOabtKJVl3O9',
#      'is_local': False,
#      'name': 'Fifteen',
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:2l9Pipz6AiVOabtKJVl3O9'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
# ...
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 249807,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/18WFFUIsewmA8g31KAeo3e'},
#      'href': 'https://api.spotify.com/v1/tracks/18WFFUIsewmA8g31KAeo3e',
#      'id': '18WFFUIsewmA8g31KAeo3e',
#      'is_local': False,
#      'name': 'The Prophecy',
#      'preview_url': None,
#      'track_number': 26,
#      'type': 'track',
#      'uri': 'spotify:track:18WFFUIsewmA8g31KAeo3e'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 240205,
#      'explicit': True,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0g4fMVo4JjwnIpTfFfLdxS'},
#      'href': 'https://api.spotify.com/v1/tracks/0g4fMVo4JjwnIpTfFfLdxS',
#      'id': '0g4fMVo4JjwnIpTfFfLdxS',
#      'is_local': False,
#      'name': 'Cassandra',
#      'preview_url': None,
#      'track_number': 27,
#      'type': 'track',
#      'uri': 'spotify:track:0g4fMVo4JjwnIpTfFfLdxS'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 283957,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3zMDGj4D8ogaYgAIZPeU7S'},
#      'href': 'https://api.spotify.com/v1/tracks/3zMDGj4D8ogaYgAIZPeU7S',
#      'id': '3zMDGj4D8ogaYgAIZPeU7S',
#      'is_local': False,
#      'name': 'Peter',
#      'preview_url': None,
#      'track_number': 28,
#      'type': 'track',
#      'uri': 'spotify:track:3zMDGj4D8ogaYgAIZPeU7S'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 238241,
#      'explicit': True,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2913xXOVAIDAqxzV2g4VcU'},
#      'href': 'https://api.spotify.com/v1/tracks/2913xXOVAIDAqxzV2g4VcU',
#      'id': '2913xXOVAIDAqxzV2g4VcU',
#      'is_local': False,
#      'name': 'The Bolter',
#      'preview_url': None,
#      'track_number': 29,
#      'type': 'track',
#      'uri': 'spotify:track:2913xXOVAIDAqxzV2g4VcU'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 240893,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2CnjDMdpRjlWv04Xk3s6MW'},
#      'href': 'https://api.spotify.com/v1/tracks/2CnjDMdpRjlWv04Xk3s6MW',
#      'id': '2CnjDMdpRjlWv04Xk3s6MW',
#      'is_local': False,
#      'name': 'Robin',
#      'preview_url': None,
#      'track_number': 30,
#      'type': 'track',
#      'uri': 'spotify:track:2CnjDMdpRjlWv04Xk3s6MW'},
#     {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'disc_number': 1,
#      'duration_ms': 224743,
#      'explicit': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1DTRUYVd8rYpla9hhVVwjo'},
#      'href': 'https://api.spotify.com/v1/tracks/1DTRUYVd8rYpla9hhVVwjo',
#      'id': '1DTRUYVd8rYpla9hhVVwjo',
#      'is_local': False,
#      'name': 'The Manuscript',
#      'preview_url': None,
#      'track_number': 31,
#      'type': 'track',
#      'uri': 'spotify:track:1DTRUYVd8rYpla9hhVVwjo'}],
#    'limit': 50,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 31},
#   'type': 'album',
#   'uri': 'spotify:album:5H7ixXZfsNMGbIE5OBSpcb'}]

# %%
dataframe_discos = {'disco':[],
                    'release_date': [],
                    'markets': [],
                    'label': [],
                    'total_tracks': []}
for disco in lista_datos_discos:
    dataframe_discos['disco'].append(disco['name'])
    dataframe_discos['release_date'].append(disco['release_date'])
    dataframe_discos['markets'].append(disco['available_markets'])
    dataframe_discos['label'].append(disco['label'])
    dataframe_discos['total_tracks'].append(disco['total_tracks'])

df = pd.DataFrame(dataframe_discos)
df.to_csv('files/general_info_albums.csv')
df
# Out:
#                                            disco release_date  \
# 0                                   Taylor Swift   2006-10-24
# 1                                       Fearless   2008-11-11
# 2                     Speak Now (Deluxe Package)   2010-01-01
# 3                           Red (Deluxe Edition)   2012-10-22
# 4                                  1989 (Deluxe)   2014-01-01
# 5                                     reputation   2017-11-10
# 6                                          Lover   2019-08-23
# 7                      folklore (deluxe version)   2020-08-18
# 8                      evermore (deluxe version)   2021-01-07
# 9                        Midnights (3am Edition)   2022-10-22
# 10  THE TORTURED POETS DEPARTMENT: THE ANTHOLOGY   2024-04-19
#
#                                               markets  \
# 0   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 1                            [BE, CH, DE, ES, GR, SE]
# 2   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 3   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 4   [AR, AU, AT, BE, BO, BR, BG, CL, CO, CR, CY, C...
# 5   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 6   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 7   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 8   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 9   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 10  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
#
#                        label  total_tracks
# 0            Universal Music            15
# 1   Big Machine Records, LLC            17
# 2   Big Machine Records, LLC            22
# 3   Big Machine Records, LLC            22
# 4   Big Machine Records, LLC            19
# 5   Big Machine Records, LLC            15
# 6               Taylor Swift            18
# 7               Taylor Swift            17
# 8                TS/Republic            17
# 9               Taylor Swift            20
# 10              Taylor Swift            31

# %%
lista_uri_tracks = []
track_info = {'name': [],
            'album': [],
            'track_number': [],
            'id': [],
            'uri': []}

for disco in [lista_datos_discos[1], lista_datos_discos[3]]:
    album_name = disco['name']
    track_info['album'].extend([album_name] * len(disco['tracks']['items']))
    for track in disco['tracks']['items']:
        track_info['name'].append(track['name'])
        track_info['track_number'].append(track['track_number'])
        track_info['id'].append(track['id'])
        track_info['uri'].append(track['uri'])

track_info_df = pd.DataFrame(track_info)
track_info_df
# Out:
#                                        name                 album  \
# 0                                  Fearless              Fearless
# 1                                   Fifteen              Fearless
# 2                                Love Story              Fearless
# 3                               Hey Stephen              Fearless
# 4                               White Horse              Fearless
# 5                        You Belong With Me              Fearless
# 6                                   Breathe              Fearless
# 7                               Tell Me Why              Fearless
# 8                          You're Not Sorry              Fearless
# 9                       The Way I Loved You              Fearless
# 10                         Forever & Always              Fearless
# 11                             The Best Day              Fearless
# 12                                   Change              Fearless
# 13                                 Our Song              Fearless
# 14                   Teardrops On My Guitar              Fearless
# 15                        Should've Said No              Fearless
# 16            Love Story - J Stax Radio Mix              Fearless
# 17                           State Of Grace  Red (Deluxe Edition)
# 18                                      Red  Red (Deluxe Edition)
# 19                              Treacherous  Red (Deluxe Edition)
# 20                 I Knew You Were Trouble.  Red (Deluxe Edition)
# 21                             All Too Well  Red (Deluxe Edition)
# 22                                       22  Red (Deluxe Edition)
# 23                              I Almost Do  Red (Deluxe Edition)
# 24  We Are Never Ever Getting Back Together  Red (Deluxe Edition)
# 25                           Stay Stay Stay  Red (Deluxe Edition)
# 26                            The Last Time  Red (Deluxe Edition)
# 27                              Holy Ground  Red (Deluxe Edition)
# 28                     Sad Beautiful Tragic  Red (Deluxe Edition)
# 29                            The Lucky One  Red (Deluxe Edition)
# 30                   Everything Has Changed  Red (Deluxe Edition)
# 31                                Starlight  Red (Deluxe Edition)
# 32                              Begin Again  Red (Deluxe Edition)
# 33                        The Moment I Knew  Red (Deluxe Edition)
# 34                      Come Back...Be Here  Red (Deluxe Edition)
# 35                             Girl At Home  Red (Deluxe Edition)
# 36    Treacherous - Original Demo Recording  Red (Deluxe Edition)
# 37            Red - Original Demo Recording  Red (Deluxe Edition)
# 38                State Of Grace - Acoustic  Red (Deluxe Edition)
#
#     track_number                      id                                   uri
# 0              1  4lIbdZwGa2hgkxigHJumaV  spotify:track:4lIbdZwGa2hgkxigHJumaV
# 1              2  2l9Pipz6AiVOabtKJVl3O9  spotify:track:2l9Pipz6AiVOabtKJVl3O9
# 2              3  0wi9VaczZO8tbBwltGiwO5  spotify:track:0wi9VaczZO8tbBwltGiwO5
# 3              4  4vwfVWo6hSf0vJuBpNwMWJ  spotify:track:4vwfVWo6hSf0vJuBpNwMWJ
# 4              5  04g3rUk3RzqaXi02FJT2Zl  spotify:track:04g3rUk3RzqaXi02FJT2Zl
# 5              6  3hD7Dd9WVVkT6HAtil3R2D  spotify:track:3hD7Dd9WVVkT6HAtil3R2D
# 6              7  5XQJNlITnzHbLqpX60gUrj  spotify:track:5XQJNlITnzHbLqpX60gUrj
# 7              8  3ZeJG2dbry1YgRbGn5IukZ  spotify:track:3ZeJG2dbry1YgRbGn5IukZ
# 8              9  5WbxKDVDEHtDWL9Mr6ZLoc  spotify:track:5WbxKDVDEHtDWL9Mr6ZLoc
# 9             10  177nprYS2qLchToEJVzTec  spotify:track:177nprYS2qLchToEJVzTec
# 10            11  0AXwcrtfYGYgQgmzyk8PA1  spotify:track:0AXwcrtfYGYgQgmzyk8PA1
# 11            12  361O1jOM9zsU5Wmo3hhsfH  spotify:track:361O1jOM9zsU5Wmo3hhsfH
# 12            13  5nUPw1RvAkqDIdebpDy3JI  spotify:track:5nUPw1RvAkqDIdebpDy3JI
# 13            14  3iaYan8tKzKGP0MNWbSgxM  spotify:track:3iaYan8tKzKGP0MNWbSgxM
# 14            15  7gfzBsM4xaMb8c2WdpzEat  spotify:track:7gfzBsM4xaMb8c2WdpzEat
# 15            16  5p0RhYSSIU86G63ugc7nAA  spotify:track:5p0RhYSSIU86G63ugc7nAA
# 16            17  4i0M7glXqIIRKPwbLtpExi  spotify:track:4i0M7glXqIIRKPwbLtpExi
# 17             1  0b16LTzby1YRVd2nq2Z0fw  spotify:track:0b16LTzby1YRVd2nq2Z0fw
# 18             2  7gJtmLyPTwKzhGzMBXtuXH  spotify:track:7gJtmLyPTwKzhGzMBXtuXH
# 19             3  7nECwCDHS1JvQbrmuorZIH  spotify:track:7nECwCDHS1JvQbrmuorZIH
# 20             4  3lKZf71jeNi14udIFPJ29V  spotify:track:3lKZf71jeNi14udIFPJ29V
# 21             5  6GNRkaWUB0Lwc19SdkTgx8  spotify:track:6GNRkaWUB0Lwc19SdkTgx8
# 22             6  3WC5CVAahvn98hiseoIvbw  spotify:track:3WC5CVAahvn98hiseoIvbw
# 23             7  1eyqSYBCTane4rl4vc6PWJ  spotify:track:1eyqSYBCTane4rl4vc6PWJ
# 24             8  6kISMRfweKSvgHR0urMQFG  spotify:track:6kISMRfweKSvgHR0urMQFG
# 25             9  0F2S1QlnMaOfmNHIgmES3k  spotify:track:0F2S1QlnMaOfmNHIgmES3k
# 26            10  2Tz4JnXZOcjcp8fWfMjBBk  spotify:track:2Tz4JnXZOcjcp8fWfMjBBk
# 27            11  3KmYVOuK2eG7LGP7qQ8DLR  spotify:track:3KmYVOuK2eG7LGP7qQ8DLR
# 28            12  70e9zuv2pJc7ON1OUAJ1zl  spotify:track:70e9zuv2pJc7ON1OUAJ1zl
# 29            13  5VQLMrWhailAhErKNUSnv1  spotify:track:5VQLMrWhailAhErKNUSnv1
# 30            14  5PjfMmF06QtxTPZBZHdhoZ  spotify:track:5PjfMmF06QtxTPZBZHdhoZ
# 31            15  1gL4vMhDV3RgJQmDuY5HK1  spotify:track:1gL4vMhDV3RgJQmDuY5HK1
# 32            16  1yG491M3fRfowMdGN5pey4  spotify:track:1yG491M3fRfowMdGN5pey4
# 33            17  4qTAwKJQ68gmnrnfPD3vlO  spotify:track:4qTAwKJQ68gmnrnfPD3vlO
# 34            18  1n8rB9AhxiAvVP1E2c3yOd  spotify:track:1n8rB9AhxiAvVP1E2c3yOd
# 35            19  6VFpuI0DDmbC5UyWZQ4IRY  spotify:track:6VFpuI0DDmbC5UyWZQ4IRY
# 36            20  7skiELMb9SiQCcBpsExIJf  spotify:track:7skiELMb9SiQCcBpsExIJf
# 37            21  2OghnlGqZZsFzHjG0CSE9l  spotify:track:2OghnlGqZZsFzHjG0CSE9l
# 38            22  5mfDBWY7ncZFm7ykmFTG4i  spotify:track:5mfDBWY7ncZFm7ykmFTG4i

# %%
track_audio_ft = {'uri': [],
            'acousticness': [],
            'danceability': [],
            'energy': [],
            'instrumentalness': [],
            'liveness': [],
            'loudness': [],
            'speechiness': [],
            'tempo': [],
            'valence': [],
            'popularity': [],
            'duration_ms': []
            }

for uri in track_info['uri']:
    datos = sp.audio_features(uri)
    track_audio_ft['uri'].append(datos[0]['uri'])
    track_audio_ft['acousticness'].append(datos[0]['acousticness'])

track_audio_ft

# %%
prueba[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
